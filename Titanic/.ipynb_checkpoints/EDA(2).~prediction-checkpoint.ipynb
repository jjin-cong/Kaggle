# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('C:/Users/jlee0/Desktop/KYU/deep learning/kaggle/Titanic/data/train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.isnull().sum()  #total null값을 계산하기 위함
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# #### How many Survived?

# %%
f, ax = plt.subplots(1,2,figsize=(18,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)  #value_counts : 어떤 column안에 있는 특정 데이터의 수를 count 해주는 것
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %% [markdown]
# 전체 인원의 38.4%만이 생존했다는 사실을 알 수 있다.
#
# 앞으로의 분석에서는 어떤 feature가 생존에 영향을 주었는지, 얼마나 주었는지를 분석하고자 한다.

# %% [markdown]
# ### Data Type
#
# 1. Categorical Features : Sex, Embarked와 같이 카테고리별로 분류될 수 있으면서 순서나 등급이 없는 데이터 타입을 의미한다.
#
# 2. Ordinal Features : Pclass와 같이 카테고리별로 분류될 수 있으면서 순서나 등급이 존재하는 데이터 타입을 의미한다.
#
# 3. Continous Feautures : Age와 같이 연속적인 값을 갖는 데이터를 의미한다.

# %% [markdown]
# ### Analysis Features

# %% [markdown]
# 1. Categorical

# %%
data.groupby(['Sex','Survived'])['Survived'].count()  #groupby : groupby([a,b])는 a,b에 대해서 data의 통계량을 구하는 것이다. 
f, ax = plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex',hue = 'Survived',data=data,ax=ax[1])
ax[1].set_title('Sex : Survived vs Dead')
plt.show()

# %% [markdown]
# 남성이 여성보다 배에 많이 탑승하였고, 여성이 남성보다 높은 생존률을 갖는다고 확인할 수 있다.
#
# --> 매우 중요한 분석!

# %% [markdown]
# ### Categorical data
#
# 2. Pclass

# %%
pd.crosstab(data.Pclass,data.Survived,margins=True).style.background_gradient(cmap='summer_r')  #데이터를 표로 재구성하는 것. 그리고 그 정도를 색의 진하기로 나타낸다.
# Out:
# <style  type="text/css" >
#     #T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99row0_col1 {
#             background-color:  #cee666;
#             color:  #000000;
#         }    #T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99row0_col2 {
#             background-color:  #f4fa66;
#             color:  #000000;
#         }    #T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99row1_col0 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99row2_col0 {
#             background-color:  #60b066;
#             color:  #000000;
#         }    #T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99row2_col1 {
#             background-color:  #dfef66;
#             color:  #000000;
#         }    #T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99row2_col2 {
#             background-color:  #90c866;
#             color:  #000000;
#         }    #T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99row3_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99row3_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99row3_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99row0_col0" class="data row0 col0" >80</td>
#                         <td id="T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99row0_col1" class="data row0 col1" >136</td>
#                         <td id="T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99row0_col2" class="data row0 col2" >216</td>
#             </tr>
#             <tr>
#                         <th id="T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99row1_col1" class="data row1 col1" >87</td>
#                         <td id="T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99row1_col2" class="data row1 col2" >184</td>
#             </tr>
#             <tr>
#                         <th id="T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99row2_col0" class="data row2 col0" >372</td>
#                         <td id="T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99row2_col1" class="data row2 col1" >119</td>
#                         <td id="T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99row2_col2" class="data row2 col2" >491</td>
#             </tr>
#             <tr>
#                         <th id="T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99level0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99row3_col0" class="data row3 col0" >549</td>
#                         <td id="T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99row3_col1" class="data row3 col1" >342</td>
#                         <td id="T_a0f91ab4_d857_11ea_ae96_74e5f95ccc99row3_col2" class="data row3 col2" >891</td>
#             </tr>
#     </tbody></table>

# %%
f,ax = plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass',hue = 'Survived',data=data,ax=ax[1])
ax[1].set_title('Pclass : Survived vs Dead')
plt.show()

# %% [markdown]
# 3등석 사람들이 가장 많았지만 가장 많이 사망한 것으로 나타난다. Pclass가 낮을수록 생존률이 높았다는 것을 확인할 수 있다.

# %% [markdown]
# #### Sex & Pclass

# %%
pd.crosstab([data.Sex,data.Survived],data.Pclass,margins = True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_db379d86_d858_11ea_91b9_74e5f95ccc99row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_db379d86_d858_11ea_91b9_74e5f95ccc99row0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_db379d86_d858_11ea_91b9_74e5f95ccc99row0_col2 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_db379d86_d858_11ea_91b9_74e5f95ccc99row0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_db379d86_d858_11ea_91b9_74e5f95ccc99row1_col0 {
#             background-color:  #96cb66;
#             color:  #000000;
#         }    #T_db379d86_d858_11ea_91b9_74e5f95ccc99row1_col1 {
#             background-color:  #a3d166;
#             color:  #000000;
#         }    #T_db379d86_d858_11ea_91b9_74e5f95ccc99row1_col2 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_db379d86_d858_11ea_91b9_74e5f95ccc99row1_col3 {
#             background-color:  #cfe766;
#             color:  #000000;
#         }    #T_db379d86_d858_11ea_91b9_74e5f95ccc99row2_col0 {
#             background-color:  #a7d366;
#             color:  #000000;
#         }    #T_db379d86_d858_11ea_91b9_74e5f95ccc99row2_col1 {
#             background-color:  #85c266;
#             color:  #000000;
#         }    #T_db379d86_d858_11ea_91b9_74e5f95ccc99row2_col2 {
#             background-color:  #6eb666;
#             color:  #000000;
#         }    #T_db379d86_d858_11ea_91b9_74e5f95ccc99row2_col3 {
#             background-color:  #85c266;
#             color:  #000000;
#         }    #T_db379d86_d858_11ea_91b9_74e5f95ccc99row3_col0 {
#             background-color:  #cde666;
#             color:  #000000;
#         }    #T_db379d86_d858_11ea_91b9_74e5f95ccc99row3_col1 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_db379d86_d858_11ea_91b9_74e5f95ccc99row3_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_db379d86_d858_11ea_91b9_74e5f95ccc99row3_col3 {
#             background-color:  #f7fb66;
#             color:  #000000;
#         }    #T_db379d86_d858_11ea_91b9_74e5f95ccc99row4_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_db379d86_d858_11ea_91b9_74e5f95ccc99row4_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_db379d86_d858_11ea_91b9_74e5f95ccc99row4_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_db379d86_d858_11ea_91b9_74e5f95ccc99row4_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_db379d86_d858_11ea_91b9_74e5f95ccc99" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_db379d86_d858_11ea_91b9_74e5f95ccc99level0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#                         <th id="T_db379d86_d858_11ea_91b9_74e5f95ccc99level1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_db379d86_d858_11ea_91b9_74e5f95ccc99row0_col0" class="data row0 col0" >3</td>
#                         <td id="T_db379d86_d858_11ea_91b9_74e5f95ccc99row0_col1" class="data row0 col1" >6</td>
#                         <td id="T_db379d86_d858_11ea_91b9_74e5f95ccc99row0_col2" class="data row0 col2" >72</td>
#                         <td id="T_db379d86_d858_11ea_91b9_74e5f95ccc99row0_col3" class="data row0 col3" >81</td>
#             </tr>
#             <tr>
#                                 <th id="T_db379d86_d858_11ea_91b9_74e5f95ccc99level1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_db379d86_d858_11ea_91b9_74e5f95ccc99row1_col0" class="data row1 col0" >91</td>
#                         <td id="T_db379d86_d858_11ea_91b9_74e5f95ccc99row1_col1" class="data row1 col1" >70</td>
#                         <td id="T_db379d86_d858_11ea_91b9_74e5f95ccc99row1_col2" class="data row1 col2" >72</td>
#                         <td id="T_db379d86_d858_11ea_91b9_74e5f95ccc99row1_col3" class="data row1 col3" >233</td>
#             </tr>
#             <tr>
#                         <th id="T_db379d86_d858_11ea_91b9_74e5f95ccc99level0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#                         <th id="T_db379d86_d858_11ea_91b9_74e5f95ccc99level1_row2" class="row_heading level1 row2" >0</th>
#                         <td id="T_db379d86_d858_11ea_91b9_74e5f95ccc99row2_col0" class="data row2 col0" >77</td>
#                         <td id="T_db379d86_d858_11ea_91b9_74e5f95ccc99row2_col1" class="data row2 col1" >91</td>
#                         <td id="T_db379d86_d858_11ea_91b9_74e5f95ccc99row2_col2" class="data row2 col2" >300</td>
#                         <td id="T_db379d86_d858_11ea_91b9_74e5f95ccc99row2_col3" class="data row2 col3" >468</td>
#             </tr>
#             <tr>
#                                 <th id="T_db379d86_d858_11ea_91b9_74e5f95ccc99level1_row3" class="row_heading level1 row3" >1</th>
#                         <td id="T_db379d86_d858_11ea_91b9_74e5f95ccc99row3_col0" class="data row3 col0" >45</td>
#                         <td id="T_db379d86_d858_11ea_91b9_74e5f95ccc99row3_col1" class="data row3 col1" >17</td>
#                         <td id="T_db379d86_d858_11ea_91b9_74e5f95ccc99row3_col2" class="data row3 col2" >47</td>
#                         <td id="T_db379d86_d858_11ea_91b9_74e5f95ccc99row3_col3" class="data row3 col3" >109</td>
#             </tr>
#             <tr>
#                         <th id="T_db379d86_d858_11ea_91b9_74e5f95ccc99level0_row4" class="row_heading level0 row4" >All</th>
#                         <th id="T_db379d86_d858_11ea_91b9_74e5f95ccc99level1_row4" class="row_heading level1 row4" ></th>
#                         <td id="T_db379d86_d858_11ea_91b9_74e5f95ccc99row4_col0" class="data row4 col0" >216</td>
#                         <td id="T_db379d86_d858_11ea_91b9_74e5f95ccc99row4_col1" class="data row4 col1" >184</td>
#                         <td id="T_db379d86_d858_11ea_91b9_74e5f95ccc99row4_col2" class="data row4 col2" >491</td>
#                         <td id="T_db379d86_d858_11ea_91b9_74e5f95ccc99row4_col3" class="data row4 col3" >891</td>
#             </tr>
#     </tbody></table>

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data=data)
plt.show()

# %% [markdown]
# Pclass3의 female과 Pclass1의 male을 비교했을 때 전자가 생존확률이 더 높은 것을 알 수 있다.
#
# --> Sex보다 Pclass가 더 유의미한 지표이다.(분석의 중요성!)

# %% [markdown]
# ### Continous Feature
#
#     3.Age

# %%
print('Oldest Passenger was of:', data['Age'].max(),'Years')
print('Youngest Passenger was of:', data['Age'].min(),'Years')
print('Average Age on the ship:',data['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %%
f,ax = plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass","Age",hue = "Survived",data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age",hue = "Survived",data = data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %% [markdown]
# ### Null Data

# %% [markdown]
# Age 섹션에서 177개의 Null값을 확인할 수 있었다. 이를 해결하기 위해서 Null값을 나머지 사람들의 Age_mean값으로 채워도 되지만 이런 경우에는 사실 4살의 어린 아이가 29살이라는 값을 부여받게 된다.
#
# --> 이를 해결하기 위해 이름을 살펴본다. 만약 앞에 Mr. 이나 Mrs. 같은 내용이 붙는다면 혹은 붙지 않는다면에 따라 다른 평균치를 채울 수 있을 것이다.

# %%
data['Initial'] = 0
for i in data:
    data['Initial'] = data.Name.str.extract('([A-Za-z]+)\.')  #([A-Za-z]+)\. : A~Z와 a~z사이의 문자를 뽑고 .로 마무리되는 문자열을 추춘하는 것이다. Mr. Mrs.를 뽑기에 좋음

# %%
pd.crosstab(data.Initial,data.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col6 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col7 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col9 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col10 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col11 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col12 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col13 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col14 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col15 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col16 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row1_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row1_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row1_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row1_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row1_col5 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row1_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row1_col7 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row1_col8 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row1_col9 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row1_col10 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row1_col11 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row1_col12 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row1_col13 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row1_col14 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row1_col15 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_394644ac_d85c_11ea_89ce_74e5f95ccc99row1_col16 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_394644ac_d85c_11ea_89ce_74e5f95ccc99" ><thead>    <tr>        <th class="index_name level0" >Initial</th>        <th class="col_heading level0 col0" >Capt</th>        <th class="col_heading level0 col1" >Col</th>        <th class="col_heading level0 col2" >Countess</th>        <th class="col_heading level0 col3" >Don</th>        <th class="col_heading level0 col4" >Dr</th>        <th class="col_heading level0 col5" >Jonkheer</th>        <th class="col_heading level0 col6" >Lady</th>        <th class="col_heading level0 col7" >Major</th>        <th class="col_heading level0 col8" >Master</th>        <th class="col_heading level0 col9" >Miss</th>        <th class="col_heading level0 col10" >Mlle</th>        <th class="col_heading level0 col11" >Mme</th>        <th class="col_heading level0 col12" >Mr</th>        <th class="col_heading level0 col13" >Mrs</th>        <th class="col_heading level0 col14" >Ms</th>        <th class="col_heading level0 col15" >Rev</th>        <th class="col_heading level0 col16" >Sir</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_394644ac_d85c_11ea_89ce_74e5f95ccc99level0_row0" class="row_heading level0 row0" >female</th>
#                         <td id="T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col2" class="data row0 col2" >1</td>
#                         <td id="T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col4" class="data row0 col4" >1</td>
#                         <td id="T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col5" class="data row0 col5" >0</td>
#                         <td id="T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col6" class="data row0 col6" >1</td>
#                         <td id="T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col8" class="data row0 col8" >0</td>
#                         <td id="T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col9" class="data row0 col9" >182</td>
#                         <td id="T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col10" class="data row0 col10" >2</td>
#                         <td id="T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col11" class="data row0 col11" >1</td>
#                         <td id="T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col12" class="data row0 col12" >0</td>
#                         <td id="T_394644ac_d85c_11ea_89ce_74e5f95ccc99row0_col13" class="data row0 col13" >125</td>
#                         <t

# %% [markdown]
# Mile과 Mme 값은 값들은 Miss를 잘못 스펠링 한 것이다. --> 값 변환을 시켜주자

# %%
data['Initial'].replace(['Mile','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)
#inplace = True : 새로운 객체를 생성하지 않고 기존 객체를 수정하는 과정
#data.replace : 결측값을 다른 값으로 교체하기

# %%
data.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.831081
# Mlle      24.000000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %% [markdown]
# #### 결측치 채우기

# %%
data.loc[(data.Age.isnull())&(data.Initial == 'Mr'),'Age'] = 33  #Age값은 null이면서 Initial은 Mr인 부분의 Age에 33을 대입
data.loc[(data.Age.isnull())&(data.Initial == 'Mrs'),'Age'] = 36
data.loc[(data.Age.isnull())&(data.Initial == 'Master'),'Age'] = 5
data.loc[(data.Age.isnull())&(data.Initial == 'Miss'),'Age'] = 22
data.loc[(data.Age.isnull())&(data.Initial == 'Other'),'Age'] = 46

# %%
data.Age.isnull().any()  #any() : 객체중 어느하나라도 True면 True를 반환. 모두 False라면 False 반환
#null_data가 모두 사라짐을 확인
# Out:
# False

# %%
f,ax = plt.subplots(1,2,figsize=(20,10))
data[data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor = 'black',color = 'red')
ax[0].set_title('Survived = 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
data[data['Survived']==1].Age.plot.hist(ax=ax[1],bins=20,edgecolor = 'black',color = 'green')
ax[1].set_title('Survived = 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
# Out:
# [<matplotlib.axis.XTick at 0x1cf4adace08>,
#  <matplotlib.axis.XTick at 0x1cf4ada5408>,
#  <matplotlib.axis.XTick at 0x1cf4aecdbc8>,
#  <matplotlib.axis.XTick at 0x1cf4aed3c48>,
#  <matplotlib.axis.XTick at 0x1cf4aed5208>,
#  <matplotlib.axis.XTick at 0x1cf4aed5588>,
#  <matplotlib.axis.XTick at 0x1cf4aed5cc8>,
#  <matplotlib.axis.XTick at 0x1cf4aedb608>,
#  <matplotlib.axis.XTick at 0x1cf4aedbe08>,
#  <matplotlib.axis.XTick at 0x1cf4aedf888>,
#  <matplotlib.axis.XTick at 0x1cf4aee4248>,
#  <matplotlib.axis.XTick at 0x1cf4ada5048>,
#  <matplotlib.axis.XTick at 0x1cf4aee8708>,
#  <matplotlib.axis.XTick at 0x1cf4aee8908>,
#  <matplotlib.axis.XTick at 0x1cf4aedf748>,
#  <matplotlib.axis.XTick at 0x1cf4ae9d388>,
#  <matplotlib.axis.XTick at 0x1cf4ae9db08>]

# %% [markdown]
# 어린아이(5세 이하)는 많이 구출 되었다. -> 여자와 아이를 먼저 구한 사실을 알 수 있다.
#
# 가장 나이가 많은 승객도 구출되었다.
#
# 가장 사망률이 높은 나이 구간은 30~40이다.

# %%
sns.factorplot('Pclass','Survived',col = 'Initial',data=data)
plt.show()

# %% [markdown]
# ### Categorical Data
#
#     5.Embarked

# %%
pd.crosstab([data.Embarked,data.Pclass],[data.Sex,data.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row0_col0 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row0_col1 {
#             background-color:  #d2e866;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row0_col2 {
#             background-color:  #f2f866;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row0_col3 {
#             background-color:  #d8ec66;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row0_col4 {
#             background-color:  #e8f466;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row1_col1 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row1_col2 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row1_col3 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row1_col4 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row2_col0 {
#             background-color:  #e6f266;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row2_col1 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row2_col2 {
#             background-color:  #eef666;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row2_col3 {
#             background-color:  #e8f466;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row2_col4 {
#             background-color:  #edf666;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row3_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row3_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row3_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row3_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row3_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row4_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row4_col1 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row4_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row4_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row4_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row5_col0 {
#             background-color:  #e3f166;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row5_col1 {
#             background-color:  #e6f266;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row5_col2 {
#             background-color:  #ecf666;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row5_col3 {
#             background-color:  #f8fc66;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row5_col4 {
#             background-color:  #ebf566;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row6_col0 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row6_col1 {
#             background-color:  #cde666;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row6_col2 {
#             background-color:  #e4f266;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row6_col3 {
#             background-color:  #bede66;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row6_col4 {
#             background-color:  #dbed66;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row7_col0 {
#             background-color:  #edf666;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row7_col1 {
#             background-color:  #bdde66;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row7_col2 {
#             background-color:  #d3e966;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row7_col3 {
#             background-color:  #dcee66;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row7_col4 {
#             background-color:  #d1e866;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row8_col0 {
#             background-color:  #52a866;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row8_col1 {
#             background-color:  #dcee66;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row8_col2 {
#             background-color:  #81c066;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row8_col3 {
#             background-color:  #b0d866;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row8_col4 {
#             background-color:  #9acc66;
#             color:  #000000;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row9_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row9_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row9_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row9_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99row9_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Sex</th>        <th class="col_heading level0 col0" colspan=2>female</th>        <th class="col_heading level0 col2" colspan=2>male</th>        <th class="col_heading level0 col4" >All</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level1" >Survived</th>        <th class="col_heading level1 col0" >0</th>        <th class="col_heading level1 col1" >1</th>        <th class="col_heading level1 col2" >0</th>        <th class="col_heading level1 col3" >1</th>        <th class="col_heading level1 col4" ></th>    </tr>    <tr>        <th class="index_name level0" >Embarked</th>        <th class="index_name level1" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99level0_row0" class="row_heading level0 row0" rowspan=3>C</th>
#                         <th id="T_8fd8ae6e_d860_11ea_a441_74e5f95ccc99level1_row0" class="row_heading level1 row0" >1</th>
#                         <td id="T_8fd8ae6e_d860_11ea_a

# %%
sns.factorplot('Embarked','Survived',data=data)
fig=plt.gcf()  #현재 객체 불러오기
fig.set_size_inches(5,6)  #크기 조절
plt.show()

# %%
f,ax = plt.subplots(2,2,figsize=(20,15))
sns.countplot('Embarked',data = data, ax=ax[0,0])
ax[0,0].set_title('No. Of Passengers Boarded')
sns.countplot('Embarked',hue = 'Sex',data = data, ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')
sns.countplot('Embarked',hue = 'Survived',data = data, ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')
sns.countplot('Embarked',hue = 'Pclass',data = data, ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2,hspace=0.5)  #subplot간의 간격 조절
plt.show()
